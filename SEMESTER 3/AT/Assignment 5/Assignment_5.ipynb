# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import sys

# -- Detect if in Own Install or in Colab
try:
    import google.colab
    OWN_INSTALL = False
except:
    OWN_INSTALL = True
    
if OWN_INSTALL:
    
  #---- Leave these definitions ON if running on laptop
  #---- Else turn OFF by putting them between ''' ... '''

  sys.path[0:0] = ['../../../../..',  '../../../../../3rdparty',  
                   '../../../..',  '../../../../3rdparty',  
                   '../../..',     '../../../3rdparty', 
                   '../..',        '../../3rdparty',
                   '..',           '../3rdparty' ]

else: # In colab
  ! if [ ! -d Jove ]; then git clone https://github.com/ganeshutah/Jove Jove; fi
  sys.path.append('./Jove')
  sys.path.append('./Jove/jove')

# -- common imports --
from jove.DotBashers import *
from jove.Def_DFA import *
from jove.Def_NFA import *
from jove.Def_RE2NFA import *
from jove.Def_NFA2RE import *
from jove.Def_md2mc import *
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Out:
# Cloning into 'Jove'...
# remote: Enumerating objects: 4845, done.
# remote: Counting objects: 100% (211/211), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 4845 (delta 125), reused 139 (delta 59), pack-reused 4634
# Receiving objects: 100% (4845/4845), 7.55 MiB | 10.91 MiB/s, done.
# Resolving deltas: 100% (3130/3130), done.
# You may use any of these help commands:
# help(ResetStNum)
# help(NxtStateStr)
#
# You may use any of these help commands:
# help(mkp_dfa)
# help(mk_dfa)
# help(totalize_dfa)
# help(addtosigma_delta)
# help(step_dfa)
# help(run_dfa)
# help(accepts_dfa)
# help(comp_dfa)
# help(union_dfa)
# help(intersect_dfa)
# help(pruneUnreach)
# help(iso_dfa)
# help(langeq_dfa)
# help(same_status)
# help(h_langeq_dfa)
# help(fixptDist)
# help(min_dfa)
# help(pairFR)
# help(state_combos)
# help(sepFinNonFin)
# help(bash_eql_classes)
# help(listminus)
# help(bash_1)
# help(mk_rep_eqc)
# help(F_of)
# help(rep_of_s)
# help(q0_of)
# help(Delta_of)
# help(mk_state_eqc_name)
#
# You may use any of these help commands:
# help(mk_nfa)
# help(totalize_nfa)
# help(step_nfa)
# help(run_nfa)
# help(ec_step_nfa)
# help(Eclosure)
# help(Echelp)
# help(accepts_nfa)
# help(nfa2dfa)
# help(n2d)
# help(inSets)
# help(rev_dfa)
# help(min_dfa_brz)
#
# You may use any of these help commands:
# help(re2nfa)
#
# You may use any of these help commands:
# help(RE2Str)
# help(mk_gnfa)
# help(mk_gnfa_from_D)
# help(dfa2nfa)
# help(del_gnfa_states)
# help(gnfa_w_REStr)
# help(del_one_gnfa_state)
# help(Edges_Exist_Via)
# help(choose_state_to_del)
# help(form_alt_RE)
# help(form_concat_RE)
# help(form_kleene_RE)
#
# You may use any of these help commands:
# help(md2mc)
# .. and if you want to dig more, then ..
# help(default_line_attr)
# help(length_ok_input_items)
# help(union_line_attr_list_fld)
# help(extend_rsltdict)
# help(form_delta)
# help(get_machine_components)

# %% [markdown]
#  # Regular Expression Overview
#
#  Regular Expressions (RE) are syntactic expressions for describing NFA.
#
#  One can think of RE as a way to assemble NFA using a few basic primitives
#
#  * Epsilon is an RE
#      - $\varepsilon$ is an $RE$
#
#  * Simple RE that are symbols
#      - a in $\Sigma$ is an $RE$
#
#  * One can concatenate RE to result in an RE
#      - a concatenation $RE_1 RE_2$ is an $RE$
#
#  * One can union RE to obtain RE
#      - a union $RE_1 + RE_2$ is an $RE$
#
#  * One can parenthesize RE to obtain RE
#      - $(RE)$ is an $RE$
#
#  * One can star RE to obtain RE
#      - $RE^*$ is an $RE$

# %% [markdown]
# # Illustration of RE cases

# %% [markdown]
#  * Epsilon is an RE
#      - $\varepsilon$ is an $RE$

# %%
dotObj_nfa(re2nfa("''"))
# Out:
# Generating LALR tables

# %% [markdown]
#  * Simple RE that are symbols
#      - a in $\Sigma$ is an $RE$

# %%
dotObj_nfa(re2nfa("a"))

# %% [markdown]
#  * One can concatenate RE to result in an RE
#      - a concatenation $RE_1 RE_2$ is an $RE$

# %% [markdown]
# ## Example of concat: ab is an RE

# %%
dotObj_nfa(re2nfa("ab"))

# %% [markdown]
# ## Example of concat: (ab) (c+d) is an RE

# %%
dotObj_nfa(re2nfa("(ab)(c+d)"))

# %% [markdown]
#  * One can union RE to obtain RE
#      - a union $RE_1 + RE_2$ is an $RE$

# %% [markdown]
# ## Example of union: a+b

# %%
dotObj_nfa(re2nfa("a+b"))

# %% [markdown]
# ## Example of union:  a* + bc

# %%
dotObj_nfa(re2nfa("a*+bc"))

# %% [markdown]
#  * One can parenthesize RE to obtain RE
#      - $(RE)$ is an $RE$
#
#  ## Parenthesization controls precedence, but has no other effect
#
#  ### E.g. (a+b)c  versus  a+bc

# %% [markdown]
# Assignment 4
#
# ---

# %% [markdown]
# ![WhatsApp Image 2021-09-20 at 01.50.25.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-09-20 at 01.50.51.jpeg](data:image/jpeg;base64,...)
# ---

# %%
FA1="ba*b"
minFA1 = min_dfa(nfa2dfa(re2nfa(FA1)))
dotObj_dfa(minFA1, FuseEdges= True)

# %% [markdown]
# ![WhatsApp Image 2021-09-20 at 01.56.11.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-09-20 at 01.56.38.jpeg](data:image/jpeg;base64,...)

# %%
FA2="1(0+1)*0"
minFA2 = min_dfa(nfa2dfa(re2nfa(FA2)))
dotObj_dfa(minFA2, FuseEdges= True)

# %% [markdown]
# ![WhatsApp Image 2021-09-20 at 01.57.21.jpeg](data:image/jpeg;base64,...)

# %%
FA3="((a+b)*(abb))"
minFA3 = min_dfa(nfa2dfa(re2nfa(FA3)))
dotObj_dfa(minFA3, FuseEdges= True)
